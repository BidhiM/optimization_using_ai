# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x,y: x**4 + y**4 + x*y
df_x = lambda x,y: 4*x**3 + y
df_y = lambda x,y: 4*y**3 + x
ddf_x = lambda x,y: 12*x**2
ddf_y = lambda x,y: 12*y**2
ddf_xy = 1
ddf_yx = 1

x0=3
y0=1
xk=[x0]
yk=[y0]

x=np.linspace(-10,10,400)
y=np.linspace(-10,10,400)
X,Y=np.meshgrid(x,y)
z=f(X,Y)
plt.figure(figsize=(6,6))
plt.contour(X,Y,z,levels=15)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x,y: x**4 + y**4 + x*y
df_x = lambda x,y: 4*x**3 + y
df_y = lambda x,y: 4*y**3 + x
ddf_x = lambda x,y: 12*x**2
ddf_y = lambda x,y: 12*y**2
ddf_xy = 1
ddf_yx = 1

iteration=10
x0=3
y0=1
xk=[x0]
yk=[y0]
alpha = 1

x=np.linspace(-10,10,400)
y=np.linspace(-10,10,400)
X,Y=np.meshgrid(x,y)
z=f(X,Y)
plt.figure(figsize=(6,6))
plt.contour(X,Y,z,levels=15)

def raw_newton(x0,y0):
    for i in range(iteration):
        det_hf=(ddf_x(x0,y0)*ddf_y(x0,y0))-(ddf_xy*ddf_yx)
        x_new=x0-((ddf_y(x0,y0)/det_hf)*df_x(x0,y0) - (ddf_yx/det_hf)*df_y(x0,y0))
        y_new=y0-((-ddf_xy/det_hf)*df_x(x0,y0) + (ddf_x(x0,y0)/det_hf)*df_y(x0,y0))
        xk.append(x_new)
        yk.append(y_new)
        x0=x_new
        y0=y_new

raw_newton(3,1)
plt.plot(xk,yk,'r--')
plt.show()
print(xk,end=' ')
print(yk,end=' ')
# Out:
# [3, 1.9953667953667953, 1.33254487778273, 1.318780256467742, 1.1722083179473943, 1.028865335082978, 0.9003514877569085, 0.7878291329055402, 0.6908795901979877, 0.6100267059783101, 0.5484394084387064] [1, 0.5003861003861003, -0.1099056913190043, -9.17137297297923, -6.1154099765057754, -4.07923257296707, -2.7239973162737465, -1.824846054499485, -1.2338529876420654, -0.8559605305112239, -0.6330195721283521]
